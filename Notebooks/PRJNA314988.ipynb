# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA314988.csv")
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET", "CITYVILLAGE"] 
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA314988.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA314988'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA314988'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {28.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'Differences in gut metabolites and microbial composition and functions between Egyptian and U.S. children are consistent with their diets'} 1
# =========================================================
# STUDY LINK
# -------------
# {28191503.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Amplicon'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Illumina'} 1
# =========================================================
# COUNTRY
# -------------
# {'Egypt'} 1
# =========================================================
# DISEASE
# -------------
# {'Healthy'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 28
# =========================================================
# STUDY DESIGN
# -------------
# {'Cohort study'} 1
# =========================================================
# BODY SITE
# -------------
# {'Gut'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA MISEQ'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'Partcipants aged in average 14  years old'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {299.0, 300.0, 301.0} 3
# =========================================================
# RUN ID
# -------------
# {'SRR3224344', 'SRR3224328', 'SRR3224327', 'SRR3224364', 'SRR3224329', 'SRR3224347', 'SRR3224335', 'SRR3224342', 'SRR3224358', 'SRR3224337', 'SRR3224338', 'SRR3224324', 'SRR3224325', 'SRR3224326', 'SRR3224341', 'SRR3224331', 'SRR3224336', 'SRR3224361', 'SRR3224333', 'SRR3224330', 'SRR3224332', 'SRR3224340', 'SRR3224363', 'SRR3224365', 'SRR3224334', 'SRR3224362', 'SRR3224343', 'SRR3224339'} 28
# =========================================================
# Sample ID
# -------------
# {'SRS1338207', 'SRS1338210', 'SRS1338223', 'SRS1338224', 'SRS1338232', 'SRS1338217', 'SRS1338216', 'SRS1338215', 'SRS1338214', 'SRS1338231', 'SRS1338225', 'SRS1338226', 'SRS1338209', 'SRS1338236', 'SRS1338213', 'SRS1338218', 'SRS1338212', 'SRS1338208', 'SRS1338230', 'SRS1338220', 'SRS1338239', 'SRS1338211', 'SRS1338229', 'SRS1338237', 'SRS1338227', 'SRS1338238', 'SRS1338228', 'SRS1338235'} 28
# =========================================================
# Sample Name
# -------------
# {'EGKHLT02', 'EGKHLT26', 'EGKHLT32', 'EGKHLT19', 'EGKHLT15', 'EGKHLT22', 'EGKHLT25', 'EGKHLT05', 'EGKHLT07', 'EGKHLT04', 'EGKHLT08', 'EGKHLT14', 'EGKHLT03', 'EGKHLT29', 'EGKHLT11', 'EGKHLT10', 'EGKHLT30', 'EGKHLT16', 'EGKHLT12', 'EGKHLT28', 'EGKHLT27', 'EGKHLT20', 'EGKHLT01', 'EGKHLT24', 'EGKHLT31', 'EGKHLT06', 'EGKHLT17', 'EGKHLT23'} 28
# =========================================================
# COLLECTION DATE
# -------------
# {'5/22/2012', '5/27/2012', '5/28/2012'} 3
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Single'} 1
# =========================================================
# LAT LON
# -------------
# {'30.013056, 31.208853'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'Stool'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan} 1
# =========================================================
# ELO
# -------------
# {nan} 1
# =========================================================
# URBANZATION
# -------------
# {'Urban'} 1
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'Giza'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V4'} 1
# =========================================================
# DIET
# -------------
# {'Mediterranean'} 1
# =========================================================
