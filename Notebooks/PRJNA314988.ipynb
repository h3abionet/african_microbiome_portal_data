# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA314988.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA314988.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA314988'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA314988'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {28.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'DIFFERENCES IN GUT METABOLITES AND MICROBIAL COMPOSITION AND FUNCTIONS BETWEEN EGYPTIAN AND U.S. CHILDREN ARE CONSISTENT WITH THEIR DIETS'} 1
# =========================================================
# STUDY LINK
# -------------
# {28191503.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ILLUMINA'} 1
# =========================================================
# COUNTRY
# -------------
# {'EGYPT'} 1
# =========================================================
# DISEASE
# -------------
# {'HEALTHY'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 28
# =========================================================
# STUDY DESIGN
# -------------
# {'COHORT STUDY'} 1
# =========================================================
# BODY SITE
# -------------
# {'GUT'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA MISEQ'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'PARTICPANTS AGED IN AVERAGE 14  YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {299.0, 300.0, 301.0} 3
# =========================================================
# RUN ID
# -------------
# {'SRR3224363', 'SRR3224341', 'SRR3224365', 'SRR3224340', 'SRR3224333', 'SRR3224330', 'SRR3224337', 'SRR3224336', 'SRR3224362', 'SRR3224364', 'SRR3224331', 'SRR3224326', 'SRR3224332', 'SRR3224324', 'SRR3224343', 'SRR3224334', 'SRR3224347', 'SRR3224338', 'SRR3224335', 'SRR3224361', 'SRR3224325', 'SRR3224328', 'SRR3224342', 'SRR3224339', 'SRR3224358', 'SRR3224327', 'SRR3224329', 'SRR3224344'} 28
# =========================================================
# Sample ID
# -------------
# {'SRS1338216', 'SRS1338238', 'SRS1338223', 'SRS1338209', 'SRS1338214', 'SRS1338236', 'SRS1338218', 'SRS1338225', 'SRS1338235', 'SRS1338208', 'SRS1338232', 'SRS1338229', 'SRS1338228', 'SRS1338212', 'SRS1338207', 'SRS1338227', 'SRS1338215', 'SRS1338210', 'SRS1338213', 'SRS1338231', 'SRS1338226', 'SRS1338230', 'SRS1338239', 'SRS1338220', 'SRS1338211', 'SRS1338224', 'SRS1338217', 'SRS1338237'} 28
# =========================================================
# Sample Name
# -------------
# {'EGKHLT23', 'EGKHLT28', 'EGKHLT03', 'EGKHLT17', 'EGKHLT31', 'EGKHLT25', 'EGKHLT16', 'EGKHLT24', 'EGKHLT08', 'EGKHLT01', 'EGKHLT32', 'EGKHLT10', 'EGKHLT11', 'EGKHLT04', 'EGKHLT30', 'EGKHLT05', 'EGKHLT02', 'EGKHLT06', 'EGKHLT12', 'EGKHLT19', 'EGKHLT07', 'EGKHLT15', 'EGKHLT22', 'EGKHLT14', 'EGKHLT27', 'EGKHLT26', 'EGKHLT29', 'EGKHLT20'} 28
# =========================================================
# COLLECTION DATE
# -------------
# {'5/28/2012', '5/27/2012', '5/22/2012'} 3
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'SINGLE'} 1
# =========================================================
# LAT LON
# -------------
# {'30.013056, 31.208853'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'STOOL'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 28
# =========================================================
# ELO
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 28
# =========================================================
# URBANZATION
# -------------
# {'URBAN'} 1
# =========================================================
# REGION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 28
# =========================================================
# CITYVILLAGE
# -------------
# {'GIZA'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V4'} 1
# =========================================================
# DIET
# -------------
# {'MEDITERRANEAN'} 1
# =========================================================
