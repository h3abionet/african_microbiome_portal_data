# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJEB2079.csv")
data.loc[data["PLATFORM"]=='454 GS-FLXTitanium', "PLATFORM"] = '454 GS-FLX TITANIUM'
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET", "CITYVILLAGE"] 
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values

# set(data["PLATFORM"])
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJEB2079.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJEB2079'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJEB2079'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {14.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'Impact of diet in shaping gut microbiota revealed by a comparative study in children from Europe and rural Africa'} 1
# =========================================================
# STUDY LINK
# -------------
# {20679230.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Amplicon'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Roche'} 1
# =========================================================
# COUNTRY
# -------------
# {'Burkina faso'} 1
# =========================================================
# DISEASE
# -------------
# {'Healthy'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 14
# =========================================================
# STUDY DESIGN
# -------------
# {'Cohort study'} 1
# =========================================================
# BODY SITE
# -------------
# {'Gut'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-FLX TITANIUM'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'Children aged from 1 to 6 years old not under antibiotics or probiotics treatment in the 6 mo before the sampling dates'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {352.0, 354.0, 356.0, 357.0, 358.0, 359.0, 366.0, 349.0, 350.0} 9
# =========================================================
# RUN ID
# -------------
# {'ERR011079', 'ERR011077', 'ERR011068', 'ERR011075', 'ERR011060', 'ERR011086', 'ERR011067', 'ERR011064', 'ERR011084', 'ERR011058', 'ERR011081', 'ERR011083', 'ERR011062', 'ERR011066'} 14
# =========================================================
# Sample ID
# -------------
# {'ERS008235', 'ERS008229', 'ERS008236', 'ERS008230', 'ERS008239', 'ERS008240', 'ERS008246', 'ERS008251', 'ERS008234', 'ERS008238', 'ERS008252', 'ERS008232', 'ERS008242', 'ERS008227'} 14
# =========================================================
# Sample Name
# -------------
# {'SAMEA732204 ERS008239', 'SAMEA732192 ERS008251', 'SAMEA732197 ERS008230', 'SAMEA732188 ERS008229', 'SAMEA732202 ERS008235', 'SAMEA732199 ERS008236', 'SAMEA732203 ERS008238', 'SAMEA732195 ERS008232', 'SAMEA732193 ERS008252', 'SAMEA732177 ERS008242', 'SAMEA732179 ERS008240', 'SAMEA732181 ERS008246', 'SAMEA732186 ERS008227', 'SAMEA732201 ERS008234'} 14
# =========================================================
# COLLECTION DATE
# -------------
# {nan} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Single'} 1
# =========================================================
# LAT LON
# -------------
# {'12.3681873, -1.5270944*'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'Stool'} 1
# =========================================================
# ETHNICITY
# -------------
# {'Mossi'} 1
# =========================================================
# ELO
# -------------
# {'Mossi'} 1
# =========================================================
# URBANZATION
# -------------
# {'Rural'} 1
# =========================================================
# REGION
# -------------
# {'Boulkiemde province'} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'Nanoro'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V5-V6'} 1
# =========================================================
# DIET
# -------------
# {'Traditional rural African diet'} 1
# =========================================================
