# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA356146.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA356146.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA356146'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA356146'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {70.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'THE MICROBIOME IN UROGENITAL SCHISTOSOMIASIS AND INDUCED BLADDER PATHOLOGIES'} 1
# =========================================================
# STUDY LINK
# -------------
# {28793309.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ION TORRENT'} 1
# =========================================================
# COUNTRY
# -------------
# {'NIGERIA'} 1
# =========================================================
# DISEASE
# -------------
# {'UROGENITAL SCHISTOSOMIASIS'} 1
# =========================================================
# DOID
# -------------
# {1394.0} 1
# =========================================================
# STUDY DESIGN
# -------------
# {'CROSS-SECTIONAL'} 1
# =========================================================
# BODY SITE
# -------------
# {'URINE'} 1
# =========================================================
# PLATFORM
# -------------
# {'ION TORRENT PGM'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'PARTICIPANTS AGED FROM 15 TO 65 YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {131.0, 44.0, 51.0, 53.0, 54.0, 58.0, 59.0, 60.0, 64.0, 71.0, 72.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 84.0, 85.0, 86.0, 87.0, 88.0, 90.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 98.0, 99.0, 100.0, 105.0, 107.0, 109.0, 110.0, 112.0, 113.0, 127.0} 42
# =========================================================
# RUN ID
# -------------
# {'SRS1841821', 'SRS1841825', 'SRS1841842', 'SRS1841828', 'SRS1841830', 'SRS1841812', 'SRS1841799', 'SRS1841839', 'SRS1841834', 'SRS1841785', 'SRS1841810', 'SRS1841814', 'SRS1841786', 'SRS1841843', 'SRS1841827', 'SRS1841816', 'SRS1841795', 'SRS1841817', 'SRS1841788', 'SRS1841807', 'SRS1841837', 'SRS1841789', 'SRS1841820', 'SRS1841823', 'SRS1841829', 'SRS1841787', 'SRS1841836', 'SRS1841781', 'SRS1841778', 'SRS1841841', 'SRS1841815', 'SRS1841845', 'SRS1841822', 'SRS1841779', 'SRS1841796', 'SRS1841819', 'SRS1841791', 'SRS1841792', 'SRS1841809', 'SRS1841780', 'SRS1841803', 'SRS1841804', 'SRS1841824', 'SRS1841783', 'SRS1841784', 'SRS1841844', 'SRS1841790', 'SRS1841806', 'SRS1841835', 'SRS1841797', 'SRS1841794', 'SRS1841831', 'SRS1841808', 'SRS1841782', 'SRS1841802', 'SRS1841838', 'SRS1841813', 'SRS1841793', 'SRS1841840', 'SRS1841847', 'SRS1841798', 'SRS1841805', 'SRS1841846', 'SRS1841833', 'SRS1841800', 'SRS1841832', 'SRS1841801', 'SRS1841826', 'SRS1841811', 'SRS1841818'} 70
# =========================================================
# Sample ID
# -------------
# {'SRP094688'} 1
# =========================================================
# Sample Name
# -------------
# {'EG138', 'EG94', 'EG22', 'EG186', 'EG169', 'EG63', 'EG26', 'EG115', 'EG143', 'EG112', 'EG136', 'EGCTNS', 'EG133', 'EG49', 'EG102', 'EG64', 'EG12', 'EG182', 'EG84', 'EG42', 'EG51', 'EG73', 'EG101', 'EG177', 'EG92', 'EG40', 'EG85', 'EG158', 'EG15', 'EG39', 'EG58', 'EG147', 'EG24', 'EG86', 'EG66', 'EG162', 'EG96', 'EG5', 'EG167', 'EG20', 'EG139', 'EG1', 'EG35', 'EG156', 'EG37', 'EG125', 'EG155', 'EG16', 'EG78', 'EG62', 'EG130', 'EG33', 'EG4', 'EG38', 'EG176', 'EG120', 'EG41', 'EG25', 'EG178', 'EG185', 'EG164', 'EG114', 'EG11', 'EG144', 'EG104', 'EG43', 'EG172', 'EG91', 'EG76', 'EG89'} 70
# =========================================================
# COLLECTION DATE
# -------------
# {'6/2/2015'} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'SINGLE'} 1
# =========================================================
# LAT LON
# -------------
# {'7.058310, 2.904010'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'URINE'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 70
# =========================================================
# ELO
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 70
# =========================================================
# URBANZATION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 70
# =========================================================
# REGION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 70
# =========================================================
# CITYVILLAGE
# -------------
# {'EGGUA'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V3'} 1
# =========================================================
# DIET
# -------------
# {'CORN SOY BLEND'} 1
# =========================================================
