# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA278393.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA278393.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA278393'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA278393'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {27.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'METAGENOME SEQUENCING OF THE HADZA HUNTER-GATHERER GUT MICROBIOTA'} 1
# =========================================================
# STUDY LINK
# -------------
# {25981789.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'WGS'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ILLUMINA'} 1
# =========================================================
# COUNTRY
# -------------
# {'TANZANIA'} 1
# =========================================================
# DISEASE
# -------------
# {'HEALTHY'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 27
# =========================================================
# STUDY DESIGN
# -------------
# {'COHORT STUDY'} 1
# =========================================================
# BODY SITE
# -------------
# {'GUT'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA GENOME ANALYZER IIX'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'PARTICIPANTS AGED FROM 8 AND 70 YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {192.0, 193.0, 194.0, 168.0, 201.0, 172.0, 185.0, 186.0, 187.0, 188.0, 189.0, 190.0, 191.0} 13
# =========================================================
# RUN ID
# -------------
# {'SRR1930144', 'SRR1930128', 'SRR1930140', 'SRR1929485', 'SRR1930134', 'SRR1930138', 'SRR1930177', 'SRR1930121', 'SRR1930176', 'SRR1930145', 'SRR1930244', 'SRR1930133', 'SRR1929563', 'SRR1930149', 'SRR1927149', 'SRR1930123', 'SRR1930132', 'SRR1930143', 'SRR1930187', 'SRR1930141', 'SRR1929574', 'SRR1929484', 'SRR1930142', 'SRR1929408', 'SRR1930122', 'SRR1930179', 'SRR1930136'} 27
# =========================================================
# Sample ID
# -------------
# {'SRS883029', 'SRS883018', 'SRS883031', 'SRS883026', 'SRS882224', 'SRS883036', 'SRS883035', 'SRS883024', 'SRS883037', 'SRS883023', 'SRS883021', 'SRS883017', 'SRS883020', 'SRS882245', 'SRS883030', 'SRS883022', 'SRS883027', 'SRS883025', 'SRS882242', 'SRS883040', 'SRS883039', 'SRS883019', 'SRS883032', 'SRS883034', 'SRS883028', 'SRS882244', 'SRS883038'} 27
# =========================================================
# Sample Name
# -------------
# {10001.0, 10002.0, 10003.0, 10004.0, 10005.0, 10006.0, 10007.0, 10008.0, 10009.0, 10010.0, 10011.0, 10012.0, 10013.0, 10014.0, 10015.0, 10016.0, 10017.0, 10018.0, 10019.0, 10020.0, 10021.0, 10022.0, 10023.0, 10024.0, 10025.0, 10026.0, 10027.0} 27
# =========================================================
# COLLECTION DATE
# -------------
# {'01/01/2013'} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'PAIRED'} 1
# =========================================================
# LAT LON
# -------------
# {'-6.814920, 39.288410*'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'STOOL'} 1
# =========================================================
# ETHNICITY
# -------------
# {'HADZA'} 1
# =========================================================
# ELO
# -------------
# {'HADZA'} 1
# =========================================================
# URBANZATION
# -------------
# {'CAMP'} 1
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'DEDAUKO // SENGELE'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 27
# =========================================================
# DIET
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 27
# =========================================================
