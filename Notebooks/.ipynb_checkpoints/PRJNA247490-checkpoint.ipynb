# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA247490.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA247490.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA247490'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA247490'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {45.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'FROM AN IMBALANCE TO A NEW IMBALANCE: ITALIAN-STYLE GLUTEN FREE_DIET ALTERS THE SALIVARY MICROBIOTA AND METABOLOME OF AFRICAN CELIAC CHILDREN'} 1
# =========================================================
# STUDY LINK
# -------------
# {26681599.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ROCHE'} 1
# =========================================================
# COUNTRY
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 45
# =========================================================
# DISEASE
# -------------
# {'CELIAC DISEASE'} 1
# =========================================================
# DOID
# -------------
# {10608.0} 1
# =========================================================
# STUDY DESIGN
# -------------
# {'COHORT STUDY'} 1
# =========================================================
# BODY SITE
# -------------
# {'ORAL'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-JUNIOR'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'CHILDREN AGED IN AVERAGE 8 YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {521.0, 536.0, 540.0, 541.0, 542.0, 543.0, 547.0, 548.0, 549.0, 550.0, 551.0, 552.0, 553.0, 554.0, 555.0, 556.0, 557.0, 558.0, 559.0, 560.0, 561.0, 562.0, 566.0} 23
# =========================================================
# RUN ID
# -------------
# {'SRR1299234', 'SRR1299249', 'SRR1299252', 'SRR1299243', 'SRR1299258', 'SRR1299245', 'SRR1299239', 'SRR1299240', 'SRR1299256', 'SRR1299248', 'SRR1299244', 'SRR1299241', 'SRR1299261', 'SRR1299265', 'SRR1299233', 'SRR1299227', 'SRR1299260', 'SRR1299264', 'SRR1299242', 'SRR1299250', 'SRR1299238', 'SRR1299222', 'SRR1299237', 'SRR1299263', 'SRR1299225', 'SRR1299232', 'SRR1299236', 'SRR1299257', 'SRR1299251', 'SRR1299254', 'SRR1299224', 'SRR1299230', 'SRR1299259', 'SRR1299262', 'SRR1299253', 'SRR1299247', 'SRR1299226', 'SRR1299231', 'SRR1299255', 'SRR1299235', 'SRR1299266', 'SRR1299223', 'SRR1299246', 'SRR1299228', 'SRR1299229'} 45
# =========================================================
# Sample ID
# -------------
# {'SRS620534', 'SRS620552', 'SRS620555', 'SRS620556', 'SRS620568', 'SRS620576', 'SRS620564', 'SRS620549', 'SRS620545', 'SRS620560', 'SRS620535', 'SRS620565', 'SRS620546', 'SRS620566', 'SRS620536', 'SRS620537', 'SRS620563', 'SRS620574', 'SRS620557', 'SRS620550', 'SRS620578', 'SRS620548', 'SRS620559', 'SRS620551', 'SRS620554', 'SRS620572', 'SRS620561', 'SRS620562', 'SRS620547', 'SRS620542', 'SRS620571', 'SRS620553', 'SRS620538', 'SRS620558', 'SRS620570', 'SRS620573', 'SRS620567', 'SRS620540', 'SRS620575', 'SRS620539', 'SRS620544', 'SRS620541', 'SRS620577', 'SRS620543', 'SRS620569'} 45
# =========================================================
# Sample Name
# -------------
# {'4T60', '26T60', '7T0', '2T60', '29T30', '28T60', '13T0', '3T30', '24T60', '4T0', '1T0', '11T30', '11T0', '18T60', '32T60', '7T30', '6T60', '31T30', '1T30', '19T30', '27T30', '13T30', '15T0', '22T60', '10T60', '16T60', '25T30', '23T30', '17T30', '30T60', '14T60', '8T60', '20T60', '14T0', '10T0', '21T30', '8T0', '5T0', '5T30', '12T60', '9T0', '9T30', '15T30', '2T0', '3T0'} 45
# =========================================================
# COLLECTION DATE
# -------------
# {2013.0} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'SINGLE'} 1
# =========================================================
# LAT LON
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 45
# =========================================================
# SAMPLE TYPE
# -------------
# {'SALIVA'} 1
# =========================================================
# ETHNICITY
# -------------
# {'SAHARAWI'} 1
# =========================================================
# ELO
# -------------
# {'SAHRAWI'} 1
# =========================================================
# URBANZATION
# -------------
# {'REFUGEE CAMP'} 1
# =========================================================
# REGION
# -------------
# {'WESTERN AFRICAN SAHARA'} 1
# =========================================================
# CITYVILLAGE
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 45
# =========================================================
# TARGET AMPLICON
# -------------
# {'V1-V3'} 1
# =========================================================
# DIET
# -------------
# {'GLUTEN FREE DIET AND AFRICAN STYLE DIETARY HABITS'} 1
# =========================================================
