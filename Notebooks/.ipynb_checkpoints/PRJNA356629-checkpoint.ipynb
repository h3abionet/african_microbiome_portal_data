# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA356629.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA356629.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA356629'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA356629'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {38.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'ATOPIC DERMATITIS AND FOOD SENSITIZATION IN SOUTH-AFRICAN TODDLERS: ROLE OF FIBER AND GUT MICROBIOTA'} 1
# =========================================================
# STUDY LINK
# -------------
# {28583264.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ILLUMINA'} 1
# =========================================================
# COUNTRY
# -------------
# {'SOUTH AFRICA'} 1
# =========================================================
# DISEASE
# -------------
# {'ATOPIC DERMATITIS'} 1
# =========================================================
# DOID
# -------------
# {3310.0} 1
# =========================================================
# STUDY DESIGN
# -------------
# {'CASE-CONTROL'} 1
# =========================================================
# BODY SITE
# -------------
# {'GUT'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA MISEQ'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'WOMEN AGED IN  AVERAGE 30 YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {602.0} 1
# =========================================================
# RUN ID
# -------------
# {'SRR5114739', 'SRR5114763', 'SRR5114744', 'SRR5114738', 'SRR5114757', 'SRR5114735', 'SRR5114743', 'SRR5114734', 'SRR5114732', 'SRR5114767', 'SRR5114740', 'SRR5114746', 'SRR5114736', 'SRR5114766', 'SRR5114737', 'SRR5114750', 'SRR5114761', 'SRR5114751', 'SRR5114749', 'SRR5114747', 'SRR5114741', 'SRR5114742', 'SRR5114760', 'SRR5114764', 'SRR5114745', 'SRR5114755', 'SRR5114758', 'SRR5114768', 'SRR5114762', 'SRR5114752', 'SRR5114748', 'SRR5114753', 'SRR5114733', 'SRR5114759', 'SRR5114769', 'SRR5114756', 'SRR5114765', 'SRR5114754'} 38
# =========================================================
# Sample ID
# -------------
# {'SRS1862718', 'SRS1862707', 'SRS1862710', 'SRS1862721', 'SRS1862694', 'SRS1862701', 'SRS1862716', 'SRS1862699', 'SRS1862709', 'SRS1862708', 'SRS1862704', 'SRS1862690', 'SRS1862725', 'SRS1862711', 'SRS1862689', 'SRS1862715', 'SRS1862724', 'SRS1862703', 'SRS1862691', 'SRS1862712', 'SRS1862692', 'SRS1862722', 'SRS1862706', 'SRS1862713', 'SRS1862720', 'SRS1862695', 'SRS1862697', 'SRS1862719', 'SRS1862688', 'SRS1862723', 'SRS1862696', 'SRS1862705', 'SRS1862702', 'SRS1862717', 'SRS1862726', 'SRS1862693', 'SRS1862698', 'SRS1862700'} 38
# =========================================================
# Sample Name
# -------------
# {900000.136, 900001.136, 900002.136, 900003.136, 900004.136, 900005.136, 900006.136, 900007.136, 900008.136, 900009.136, 900010.136, 900011.136, 900012.136, 900013.136, 900014.136, 900015.136, 900016.136, 900017.136, 900018.136, 900019.136, 900020.136, 900021.136, 900022.136, 900023.136, 900024.136, 900025.136, 900026.136, 900027.136, 900028.136, 900029.136, 900030.136, 900031.136, 900032.136, 900033.136, 900034.136, 900035.136, 900036.136, 900038.136} 38
# =========================================================
# COLLECTION DATE
# -------------
# {2015.0} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'PAIRED'} 1
# =========================================================
# LAT LON
# -------------
# {'-33.924870, 18.424055'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'STOOL'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 38
# =========================================================
# ELO
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 38
# =========================================================
# URBANZATION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 38
# =========================================================
# REGION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 38
# =========================================================
# CITYVILLAGE
# -------------
# {'CAPE TOWN'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V4'} 1
# =========================================================
# DIET
# -------------
# {'DETAILED QUESTIONNAIRES AVAILABLE'} 1
# =========================================================
