# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJEB2079.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJEB2079.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJEB2079'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJEB2079'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {14.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'IMPACT OF DIET IN SHAPING GUT MICROBIOTA REVEALED BY A COMPARATIVE STUDY IN CHILDREN FROM EUROPE AND RURAL AFRICA'} 1
# =========================================================
# STUDY LINK
# -------------
# {20679230.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ROCHE'} 1
# =========================================================
# COUNTRY
# -------------
# {'BURKINA FASO'} 1
# =========================================================
# DISEASE
# -------------
# {'HEALTHY'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 14
# =========================================================
# STUDY DESIGN
# -------------
# {'COHORT STUDY'} 1
# =========================================================
# BODY SITE
# -------------
# {'GUT'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-FLXTITANIUM'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'CHILDREN AGED FROM 1 TO 6 YEARS OLD NOT UNDER ANTIBIOTICS OR PROBIOTICS TREATMENT IN THE 6 MO BEFORE THE SAMPLING DATES'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {352.0, 354.0, 356.0, 357.0, 358.0, 359.0, 366.0, 349.0, 350.0} 9
# =========================================================
# RUN ID
# -------------
# {'ERR011062', 'ERR011058', 'ERR011064', 'ERR011079', 'ERR011077', 'ERR011068', 'ERR011081', 'ERR011075', 'ERR011086', 'ERR011067', 'ERR011083', 'ERR011066', 'ERR011084', 'ERR011060'} 14
# =========================================================
# Sample ID
# -------------
# {'ERS008238', 'ERS008239', 'ERS008234', 'ERS008229', 'ERS008246', 'ERS008227', 'ERS008240', 'ERS008251', 'ERS008230', 'ERS008232', 'ERS008235', 'ERS008236', 'ERS008252', 'ERS008242'} 14
# =========================================================
# Sample Name
# -------------
# {'SAMEA732195 ERS008232', 'SAMEA732188 ERS008229', 'SAMEA732186 ERS008227', 'SAMEA732201 ERS008234', 'SAMEA732181 ERS008246', 'SAMEA732179 ERS008240', 'SAMEA732192 ERS008251', 'SAMEA732199 ERS008236', 'SAMEA732197 ERS008230', 'SAMEA732202 ERS008235', 'SAMEA732203 ERS008238', 'SAMEA732193 ERS008252', 'SAMEA732177 ERS008242', 'SAMEA732204 ERS008239'} 14
# =========================================================
# COLLECTION DATE
# -------------
# {nan} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'SINGLE'} 1
# =========================================================
# LAT LON
# -------------
# {'12.3681873, -1.5270944*'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'STOOL'} 1
# =========================================================
# ETHNICITY
# -------------
# {'MOSSI'} 1
# =========================================================
# ELO
# -------------
# {'MOSSI'} 1
# =========================================================
# URBANZATION
# -------------
# {'RURAL'} 1
# =========================================================
# REGION
# -------------
# {'BOULKIEMDE PROVINCE'} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'NANORO'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V5-V6'} 1
# =========================================================
# DIET
# -------------
# {'TRADITIONAL RURAL AFRICAN DIET'} 1
# =========================================================
