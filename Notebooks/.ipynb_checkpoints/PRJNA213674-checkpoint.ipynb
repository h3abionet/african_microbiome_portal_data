# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA213674.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA213674.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA213674'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA213674'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {66.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'HIGH DIVERSITY OF THE SALIVA MICROBIOME IN BATWA PYGMIES // COMPARATIVE ANALYSIS OF THE HUMAN SALIVA MICROBIOME FROM DIFFERENT CLIMATE ZONES: ALASKA, GERMANY AND AFRICA'} 1
# =========================================================
# STUDY LINK
# -------------
# {'21858083 // 25515234'} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ROCHE'} 1
# =========================================================
# COUNTRY
# -------------
# {'DEMOCRATIC REPUBLIC OF THE CONGO', 'UGANDA', 'SIERRA LEONE'} 3
# =========================================================
# DISEASE
# -------------
# {'HEALTHY'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 66
# =========================================================
# STUDY DESIGN
# -------------
# {'COHORT STUDY'} 1
# =========================================================
# BODY SITE
# -------------
# {'ORAL'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-FLX'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'PARTICIPANTS AGED FROM 20 TO 40 YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {256.0, 258.0, 259.0, 260.0, 261.0, 262.0, 263.0, 264.0, 266.0, 267.0, 207.0, 234.0, 237.0, 242.0, 243.0, 246.0, 247.0, 248.0, 249.0, 251.0, 252.0, 253.0, 254.0} 23
# =========================================================
# RUN ID
# -------------
# {'SRR945711', 'SRR945687', 'SRR945686', 'SRR945822', 'SRR945643', 'SRR945820', 'SRR945636', 'SRR945685', 'SRR945646', 'SRR945647', 'SRR945707', 'SRR945700', 'SRR945821', 'SRR945653', 'SRR945649', 'SRR945709', 'SRR945703', 'SRR945656', 'SRR945706', 'SRR945713', 'SRR945704', 'SRR945808', 'SRR945672', 'SRR945705', 'SRR945661', 'SRR945702', 'SRR945717', 'SRR945817', 'SRR945677', 'SRR945632', 'SRR945715', 'SRR945645', 'SRR945708', 'SRR945712', 'SRR945699', 'SRR945813', 'SRR945814', 'SRR945710', 'SRR945642', 'SRR945818', 'SRR945823', 'SRR945815', 'SRR945701', 'SRR945692', 'SRR945651', 'SRR945650', 'SRR945671', 'SRR945718', 'SRR945819', 'SRR945694', 'SRR945644', 'SRR945716', 'SRR945652', 'SRR945693', 'SRR945635', 'SRR945678', 'SRR945824', 'SRR945698', 'SRR945631', 'SRR945648', 'SRR945666', 'SRR945697', 'SRR945655', 'SRR945696', 'SRR945816', 'SRR945714'} 66
# =========================================================
# Sample ID
# -------------
# {'SRS465847', 'SRS465846', 'SRS465688', 'SRS465700', 'SRS465810', 'SRS465704', 'SRS465816', 'SRS465694', 'SRS465698', 'SRS465790', 'SRS465780', 'SRS465802', 'SRS465785', 'SRS465841', 'SRS465850', 'SRS465842', 'SRS465849', 'SRS465799', 'SRS465702', 'SRS465811', 'SRS465797', 'SRS465813', 'SRS465796', 'SRS465801', 'SRS465803', 'SRS465839', 'SRS465703', 'SRS465697', 'SRS465843', 'SRS465805', 'SRS465787', 'SRS465832', 'SRS465848', 'SRS465809', 'SRS465808', 'SRS465789', 'SRS465845', 'SRS465807', 'SRS465693', 'SRS465798', 'SRS465699', 'SRS465793', 'SRS465687', 'SRS465691', 'SRS465800', 'SRS465690', 'SRS465696', 'SRS465840', 'SRS465844', 'SRS465783', 'SRS465794', 'SRS465782', 'SRS465784', 'SRS465804', 'SRS465701', 'SRS465792', 'SRS465777', 'SRS465806', 'SRS465812', 'SRS465814', 'SRS465795', 'SRS465705', 'SRS465706', 'SRS465815', 'SRS465791', 'SRS465695'} 66
# =========================================================
# Sample Name
# -------------
# {'BATWA_PYGMY45', 'BATWA_PYGMY60', 'DRC53', 'SL33', 'BATWA_PYGMY53', 'BATWA_PYGMY65', 'BATWA_PYGMY51', 'BATWA_PYGMY67', 'DRC21', 'BATWA_PYGMY1', 'DRC60', 'BATWA_PYGMY71', 'BATWA_PYGMY22', 'SL2', 'BATWA_PYGMY37', 'SL49', 'SL57', 'SL41', 'BATWA_PYGMY49', 'BATWA_PYGMY26', 'BATWA_PYGMY20', 'SL1', 'SL25', 'SL17', 'BATWA_PYGMY66', 'BATWA_PYGMY27', 'BATWA_PYGMY54', 'BATWA_PYGMY11', 'BATWA_PYGMY35', 'BATWA_PYGMY56', 'BATWA_PYGMY61', 'BATWA_PYGMY5', 'DRC37', 'DRC84', 'DRC12', 'SL65', 'DRC44', 'BATWA_PYGMY46', 'BATWA_PYGMY7', 'DRC76', 'DRC68', 'BATWA_PYGMY47', 'BATWA_PYGMY52', 'SL9', 'BATWA_PYGMY63', 'BATWA_PYGMY36', 'DRC61', 'DRC36', 'SL73', 'DRC52', 'BATWA_PYGMY83', 'BATWA_PYGMY23', 'BATWA_PYGMY58', 'DRC45', 'DRC69', 'BATWA_PYGMY24', 'BATWA_PYGMY55', 'BATWA_PYGMY32', 'BATWA_PYGMY64', 'DRC92', 'SL89', 'SL81', 'BATWA_PYGMY72', 'BATWA_PYGMY70', 'BATWA_PYGMY73', 'BATWA_PYGMY19'} 66
# =========================================================
# COLLECTION DATE
# -------------
# {'10/21/2008', '4/25/2008'} 2
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'SINGLE'} 1
# =========================================================
# LAT LON
# -------------
# {'0.347596, 32.582520*', '8.482050, -13.213670', '-4.441931, 15.266293'} 3
# =========================================================
# SAMPLE TYPE
# -------------
# {'SALIVA'} 1
# =========================================================
# ETHNICITY
# -------------
# {'Batwa', nan} 2
# =========================================================
# ELO
# -------------
# {'Twa', nan} 2
# =========================================================
# URBANZATION
# -------------
# {'URBAN', 'RURAL'} 2
# =========================================================
# REGION
# -------------
# {nan, ' '} 2
# =========================================================
# CITYVILLAGE
# -------------
# {'KINSHASA', 'MPUNGO // MUKONGORO // KITARIRO // NYAKATARE // BIKUTO COMMUINITIES OF BUHOMA', 'FREETOWN'} 3
# =========================================================
# TARGET AMPLICON
# -------------
# {'V1-V2'} 1
# =========================================================
# DIET
# -------------
# {'FARMER LIFESTYLE', 'HUNTER GATHERERS DIET'} 2
# =========================================================
