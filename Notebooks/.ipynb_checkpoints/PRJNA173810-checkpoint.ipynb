# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA173810.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA173810.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA173810'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA173810'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {33.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'THE SALIVA MICROBIOME OF PAN AND HOMO'} 1
# =========================================================
# STUDY LINK
# -------------
# {24025115.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ROCHE'} 1
# =========================================================
# COUNTRY
# -------------
# {'SIERRA LEONE', 'DEMOCRATIC REPUBLIC OF THE CONGO'} 2
# =========================================================
# DISEASE
# -------------
# {'HEALTHY'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# STUDY DESIGN
# -------------
# {'CROSS-SECTIONAL'} 1
# =========================================================
# BODY SITE
# -------------
# {'ORAL'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-FLX'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'PARTICPANTS AGED FROM 20 TO 40 YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {256.0, 258.0, 260.0, 261.0, 262.0, 267.0, 207.0, 231.0, 234.0, 237.0, 238.0, 242.0, 243.0, 246.0, 247.0, 248.0, 249.0, 251.0, 252.0, 253.0, 254.0, 255.0} 22
# =========================================================
# RUN ID
# -------------
# {'SRR927273', 'SRR927282', 'SRR927268', 'SRR927292', 'SRR927270', 'SRR927269', 'SRR927276', 'SRR927283', 'SRR927279', 'SRR927267', 'SRR927272', 'SRR927291', 'SRR927278', 'SRR927294', 'SRR927266', 'SRR927280', 'SRR927274', 'SRR927284', 'SRR927287', 'SRR927277', 'SRR927265', 'SRR927288', 'SRR927271', 'SRR927275', 'SRR927293', 'SRR927290', 'SRR927295', 'SRR927297', 'SRR927285', 'SRR927289', 'SRR927286', 'SRR927281', 'SRR927296'} 33
# =========================================================
# Sample ID
# -------------
# {'SRS455757', 'SRS455779', 'SRS455782', 'SRS455760', 'SRS455783', 'SRS455770', 'SRS455761', 'SRS455784', 'SRS455785', 'SRS455769', 'SRS455767', 'SRS455787', 'SRS455778', 'SRS455759', 'SRS455775', 'SRS455763', 'SRS455774', 'SRS455776', 'SRS455788', 'SRS455780', 'SRS455777', 'SRS455771', 'SRS455789', 'SRS455773', 'SRS455765', 'SRS455766', 'SRS455772', 'SRS455764', 'SRS455762', 'SRS455758', 'SRS455768', 'SRS455786', 'SRS455781'} 33
# =========================================================
# Sample Name
# -------------
# {'HUMAN_DRC-68', 'HUMAN_SL-73', 'HUMAN_DRC-13', 'HUMAN_SL-17', 'HUMAN_SL-9', 'HUMAN_DRC-84', 'HUMAN_SL-41', 'HUMAN_SL-89', 'HUMAN_DRC-36', 'HUMAN_DRC-37', 'HUMAN_DRC-21', 'HUMAN_DRC-29', 'HUMAN_DRC-60', 'HUMAN_SL-57', 'HUMAN_SL-2', 'HUMAN_DRC-69', 'HUMAN_SL-49', 'HUMAN_DRC-44', 'HUMAN_DRC-76', 'HUMAN_DRC-12', 'HUMAN_DRC-5', 'HUMAN_DRC-61', 'HUMAN_DRC-28', 'HUMAN_SL-81', 'HUMAN_SL-1', 'HUMAN_DRC-53', 'HUMAN_DRC-92', 'HUMAN_DRC-20', 'HUMAN_SL-25', 'HUMAN_DRC-52', 'HUMAN_SL-65', 'HUMAN_DRC-45', 'HUMAN_SL-33'} 33
# =========================================================
# COLLECTION DATE
# -------------
# {'8/7/2013'} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'SINGLE'} 1
# =========================================================
# LAT LON
# -------------
# {'8.482050, -13.213670*', '-4.441931, 15.266293*'} 2
# =========================================================
# SAMPLE TYPE
# -------------
# {'SALIVA'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# ELO
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# URBANZATION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# REGION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# CITYVILLAGE
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# TARGET AMPLICON
# -------------
# {'V1-V2'} 1
# =========================================================
# DIET
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
