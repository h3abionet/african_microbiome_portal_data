# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA388365.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA388365.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA388365'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA388365'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {19.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'ILLUMINA MISEQ SEQUENCING FOR PRELIMINARY ANALYSIS OF MICROBIOME CAUSING PRIMARY ENDODONTIC INFECTIONS IN EGYPT'} 1
# =========================================================
# STUDY LINK
# -------------
# {29849646.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ILLUMINA'} 1
# =========================================================
# COUNTRY
# -------------
# {'EGYPT'} 1
# =========================================================
# DISEASE
# -------------
# {'PERIODONTITIS'} 1
# =========================================================
# DOID
# -------------
# {824.0} 1
# =========================================================
# STUDY DESIGN
# -------------
# {'DESCRIPTIVE STUDY'} 1
# =========================================================
# BODY SITE
# -------------
# {'ORAL'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA MISEQ'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'ADULTS AGED 31 YEARS OLD IN AVERAGE WITH CARIOUS LESIONS, NECROTIC PULPS, AND RADIOGRAPHIC EVIDENCE OF APICAL PERIRADICULAR DISEASE'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {546.0, 579.0, 581.0, 584.0, 588.0, 589.0, 590.0, 591.0, 593.0, 594.0, 595.0, 596.0, 533.0, 598.0, 536.0, 569.0, 574.0} 17
# =========================================================
# RUN ID
# -------------
# {'SRR5626929', 'SRR5626944', 'SRR5626936', 'SRR5626932', 'SRR5626941', 'SRR5626937', 'SRR5626928', 'SRR5626930', 'SRR5626934', 'SRR5626933', 'SRR5626938', 'SRR5626927', 'SRR5626940', 'SRR5626943', 'SRR5626939', 'SRR5626931', 'SRR5626935', 'SRR5626942', 'SRR5626926'} 19
# =========================================================
# Sample ID
# -------------
# {'SRS2237882', 'SRS2237867', 'SRS2237875', 'SRS2237876', 'SRS2237880', 'SRS2237866', 'SRS2237873', 'SRS2237871', 'SRS2237878', 'SRS2237865', 'SRS2237883', 'SRS2237874', 'SRS2237868', 'SRS2237881', 'SRS2237870', 'SRS2237879', 'SRS2237869', 'SRS2237877', 'SRS2237872'} 19
# =========================================================
# Sample Name
# -------------
# {'SALLYALI2', 'SALLYALI11', 'SALLYALI12', 'SALLYALI10', 'SALLYALI17', 'SALLYALI9', 'SALLYALI1', 'SALLYALI3', 'SALLYALI14', 'SALLYALI7', 'SALLYALI5', 'SALLYALI18', 'SALLYALI4', 'SALLYALI13', 'SALLYALI20', 'SALLYALI16', 'SALLYALI8', 'SALLYALI15', 'SALLYALI6'} 19
# =========================================================
# COLLECTION DATE
# -------------
# {'04/15/2016', '04/16/2016', '04/21/2016', '04/17/2016', '04/20/2016', '04/18/2016', '04/19/2016', '04/22/2016'} 8
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'PAIRED'} 1
# =========================================================
# LAT LON
# -------------
# {'30.044420, 31.235712*'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'TOOTH ROOT'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 19
# =========================================================
# ELO
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 19
# =========================================================
# URBANZATION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 19
# =========================================================
# REGION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 19
# =========================================================
# CITYVILLAGE
# -------------
# {'ISMAILIA'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V3-V4'} 1
# =========================================================
# DIET
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 19
# =========================================================
