# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA762668.csv")
data.columns = [c.upper() for c in data.columns]
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET", "CITYVILLAGE"] 
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values
data['DIET'] = np.nan
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA762668.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA762668'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA762668'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {33.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'Longitudinal and comparative analysis of gut microbiota of tunisian newborns according to delivery mode'} 1
# =========================================================
# STUDY LINK
# -------------
# {35547149.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Wgs'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Illumina'} 1
# =========================================================
# COUNTRY
# -------------
# {'Tunisia'} 1
# =========================================================
# DISEASE
# -------------
# {'Healthy'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# STUDY DESIGN
# -------------
# {'Longitudinal'} 1
# =========================================================
# BODY SITE
# -------------
# {'Gut'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA NOVASEQ 6000'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'Full-term newborns delivered by elective cesarean section at day 15', 'Full-term newborns vaginally delivered at day 15', 'Full-term newborns vaginally delivered at day 0', 'Full-term newborns vaginally delivered at day 30', 'Full-term newborns delivered by elective cesarean section at day 0', 'Full-term newborns delivered by elective cesarean section at day 30'} 6
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# RUN ID
# -------------
# {'SRR15861848', 'SRR15861836', 'SRR15861845', 'SRR15861841', 'SRR15861828', 'SRR15861829', 'SRR15861842', 'SRR15861850', 'SRR15861827', 'SRR15861826', 'SRR15861839', 'SRR15861847', 'SRR15861856', 'SRR15861849', 'SRR15861855', 'SRR15861838', 'SRR15861835', 'SRR15861824', 'SRR15861834', 'SRR15861831', 'SRR15861832', 'SRR15861840', 'SRR15861825', 'SRR15861851', 'SRR15861833', 'SRR15861843', 'SRR15861852', 'SRR15861846', 'SRR15861844', 'SRR15861830', 'SRR15861837', 'SRR15861853', 'SRR15861854'} 33
# =========================================================
# SAMPLE ID
# -------------
# {'SAMN21400408', 'SAMN21400413', 'SAMN21400399', 'SAMN21400397', 'SAMN21400412', 'SAMN21400426', 'SAMN21400421', 'SAMN21400417', 'SAMN21400423', 'SAMN21400396', 'SAMN21400414', 'SAMN21400418', 'SAMN21400401', 'SAMN21400425', 'SAMN21400409', 'SAMN21400395', 'SAMN21400398', 'SAMN21400407', 'SAMN21400411', 'SAMN21400427', 'SAMN21400410', 'SAMN21400424', 'SAMN21400404', 'SAMN21400405', 'SAMN21400402', 'SAMN21400406', 'SAMN21400420', 'SAMN21400419', 'SAMN21400400', 'SAMN21400403', 'SAMN21400415', 'SAMN21400416', 'SAMN21400422'} 33
# =========================================================
# SAMPLE NAME
# -------------
# {'T3_J15', 'T3_J30', 'Z4_J15', 'T3_J0_REP1', 'T2_J30', 'T5_J15', 'T2_J0', 'Z2_J30', 'Z2_J0_REP2', 'T6_J30', 'T1_J15_REP2', 'Z9_J15', 'Z4_J0', 'Z2_J0_REP1', 'Z7_J0', 'T5_J30', 'Z9_J0', 'T1_J15_REP1', 'T5_J0', 'Z8_J30_REP2', 'T3_J0_REP2', 'Z9_J30', 'Z8_J30_REP1', 'T1_J30', 'Z7_J30', 'Z8_J0', 'Z8_J15', 'T1_J0', 'Z4_J30', 'T6_J15', 'Z2_J15', 'T6_J0', 'Z7_J15'} 33
# =========================================================
# COLLECTION DATE
# -------------
# {'2019-02-05', '2019-06-18', '2019-01-30', '2019-01-03', '2019-01-22', '2018-12-18', '2019-01-21', '2019-02-15', '2019-07-26', '2019-09-12', '2019-02-01', '2019-01-16', '2019-05-15', '2019-06-27', '2019-05-20', '2019-11-10', '2019-04-29', '2019-01-02', '2019-03-06', '2019-12-07', '2019-05-29', '2019-02-13', '2019-02-18', '2019-09-26', '2019-08-01', '2018-12-25'} 26
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Paired'} 1
# =========================================================
# LAT LON
# -------------
# {'36.40304696765746,10.1407993988715*'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'Stool'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan} 1
# =========================================================
# ELO
# -------------
# {nan} 1
# =========================================================
# URBANZATION
# -------------
# {'Semi-rural'} 1
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'Zaghouan'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# DIET
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================

# %%
data.columns
# Out:
# Index(['REPOSITORY ID', 'REPOSITORY LINK', 'SAMPLE NUMBER', 'STUDY TITLE',
#        'STUDY LINK', 'ASSAY TYPE', 'TECHNOLOGY', 'COUNTRY', 'DISEASE', 'DOID',
#        'STUDY DESIGN', 'BODY SITE', 'PLATFORM', 'PARTICIPANT FEATURES',
#        'AVERAGE SPOTLENGTH', 'Run ID', 'Sample ID', 'Sample Name',
#        'COLLECTION DATE', 'LIBRARY LAYOUT', 'LAT LON', 'Sample Type',
#        'ETHNICITY', 'ELO', 'URBANZATION', 'REGION', 'CITYVILLAGE',
#        'TARGET AMPLICON', 'DIET'],
#       dtype='object')
