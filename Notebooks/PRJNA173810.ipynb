# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA173810.csv")
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET", "CITYVILLAGE"] 
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA173810.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA173810'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA173810'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {33.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'The saliva microbiome of pan and homo'} 1
# =========================================================
# STUDY LINK
# -------------
# {24025115.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Amplicon'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Roche'} 1
# =========================================================
# COUNTRY
# -------------
# {'Democratic republic of the congo', 'Sierra leone'} 2
# =========================================================
# DISEASE
# -------------
# {'Healthy'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 33
# =========================================================
# STUDY DESIGN
# -------------
# {'Cross-sectional'} 1
# =========================================================
# BODY SITE
# -------------
# {'Oral'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-FLX'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'Particpants aged from 20 to 40 years old'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {256.0, 258.0, 260.0, 261.0, 262.0, 267.0, 207.0, 231.0, 234.0, 237.0, 238.0, 242.0, 243.0, 246.0, 247.0, 248.0, 249.0, 251.0, 252.0, 253.0, 254.0, 255.0} 22
# =========================================================
# RUN ID
# -------------
# {'SRR927288', 'SRR927271', 'SRR927282', 'SRR927278', 'SRR927293', 'SRR927279', 'SRR927289', 'SRR927275', 'SRR927266', 'SRR927296', 'SRR927280', 'SRR927272', 'SRR927297', 'SRR927287', 'SRR927276', 'SRR927284', 'SRR927269', 'SRR927273', 'SRR927291', 'SRR927267', 'SRR927292', 'SRR927290', 'SRR927270', 'SRR927286', 'SRR927265', 'SRR927281', 'SRR927294', 'SRR927295', 'SRR927285', 'SRR927277', 'SRR927274', 'SRR927283', 'SRR927268'} 33
# =========================================================
# Sample ID
# -------------
# {'SRS455759', 'SRS455789', 'SRS455788', 'SRS455783', 'SRS455782', 'SRS455763', 'SRS455776', 'SRS455758', 'SRS455761', 'SRS455781', 'SRS455778', 'SRS455775', 'SRS455760', 'SRS455771', 'SRS455768', 'SRS455769', 'SRS455785', 'SRS455770', 'SRS455764', 'SRS455774', 'SRS455757', 'SRS455766', 'SRS455772', 'SRS455780', 'SRS455765', 'SRS455784', 'SRS455786', 'SRS455779', 'SRS455777', 'SRS455773', 'SRS455787', 'SRS455767', 'SRS455762'} 33
# =========================================================
# Sample Name
# -------------
# {'HUMAN_DRC-69', 'HUMAN_DRC-44', 'HUMAN_DRC-92', 'HUMAN_DRC-61', 'HUMAN_SL-1', 'HUMAN_SL-65', 'HUMAN_DRC-13', 'HUMAN_DRC-29', 'HUMAN_DRC-12', 'HUMAN_DRC-37', 'HUMAN_DRC-21', 'HUMAN_DRC-68', 'HUMAN_SL-49', 'HUMAN_SL-81', 'HUMAN_SL-41', 'HUMAN_SL-2', 'HUMAN_SL-57', 'HUMAN_SL-17', 'HUMAN_DRC-5', 'HUMAN_DRC-28', 'HUMAN_DRC-60', 'HUMAN_SL-33', 'HUMAN_DRC-45', 'HUMAN_SL-25', 'HUMAN_DRC-84', 'HUMAN_SL-73', 'HUMAN_DRC-53', 'HUMAN_DRC-52', 'HUMAN_DRC-20', 'HUMAN_DRC-36', 'HUMAN_SL-89', 'HUMAN_SL-9', 'HUMAN_DRC-76'} 33
# =========================================================
# COLLECTION DATE
# -------------
# {'8/7/2013'} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Single'} 1
# =========================================================
# LAT LON
# -------------
# {'-4.441931, 15.266293*', '8.482050, -13.213670*'} 2
# =========================================================
# SAMPLE TYPE
# -------------
# {'Saliva'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan} 1
# =========================================================
# ELO
# -------------
# {nan} 1
# =========================================================
# URBANZATION
# -------------
# {nan} 1
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {nan} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V1-V2'} 1
# =========================================================
# DIET
# -------------
# {nan} 1
# =========================================================
