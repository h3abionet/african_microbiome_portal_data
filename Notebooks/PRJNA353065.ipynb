# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA353065.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA353065.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA353065'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA353065'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {24.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'GUT BACTERIAL COMMUNITIES OF DIARRHEIC PATIENTS WITH INDICATIONS OF CLOSTRIDIOIDES DIFFICILE INFECTION'} 1
# =========================================================
# STUDY LINK
# -------------
# {29039846.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ILLUMINA'} 1
# =========================================================
# COUNTRY
# -------------
# {'GHANA'} 1
# =========================================================
# DISEASE
# -------------
# {'CLOSTRIDIOIDES DIFFICILE INFECTION'} 1
# =========================================================
# DOID
# -------------
# {60185.0} 1
# =========================================================
# STUDY DESIGN
# -------------
# {'CASE-CONTROL'} 1
# =========================================================
# BODY SITE
# -------------
# {'GUT'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA MISEQ'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'STANDARDISED QUESTIONNAIRE ABOUT THEIR LIFESTYLE AND MEDICAL HISTORY COLLECTED'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {600.0, 601.0, 598.0, 599.0} 4
# =========================================================
# RUN ID
# -------------
# {'SRR5040676', 'SRR5040687', 'SRR5040694', 'SRR5040688', 'SRR5040695', 'SRR5040718', 'SRR5040691', 'SRR5040722', 'SRR5040716', 'SRR5040670', 'SRR5040685', 'SRR5040734', 'SRR5040701', 'SRR5040690', 'SRR5040736', 'SRR5040668', 'SRR5040669', 'SRR5040710', 'SRR5040699', 'SRR5040714', 'SRR5040743', 'SRR5040730', 'SRR5040737', 'SRR5040700'} 24
# =========================================================
# Sample ID
# -------------
# {'SRS1811011', 'SRS1811004', 'SRS1811023', 'SRS1811036', 'SRS1811057', 'SRS1811035', 'SRS1811072', 'SRS1811071', 'SRS1811030', 'SRS1811003', 'SRS1811053', 'SRS1811051', 'SRS1811029', 'SRS1811026', 'SRS1811022', 'SRS1811049', 'SRS1811025', 'SRS1811020', 'SRS1811045', 'SRS1811079', 'SRS1811069', 'SRS1811066', 'SRS1811034', 'SRS1811005'} 24
# =========================================================
# Sample Name
# -------------
# {'PATIENT_048', 'PATIENT_054', 'PATIENT_039', 'PATIENT_044', 'PATIENT_052', 'PATIENT_036', 'PATIENT_038', 'PATIENT_047', 'PATIENT_049', 'PATIENT_057', 'PATIENT_041', 'PATIENT_055', 'PATIENT_034', 'PATIENT_042', 'PATIENT_050', 'PATIENT_053', 'PATIENT_046', 'PATIENT_051', 'PATIENT_043', 'PATIENT_040', 'PATIENT_056', 'PATIENT_037', 'PATIENT_035', 'PATIENT_045'} 24
# =========================================================
# COLLECTION DATE
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 24
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'PAIRED'} 1
# =========================================================
# LAT LON
# -------------
# {'-4.429180, 17.592120'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'STOOL'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 24
# =========================================================
# ELO
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 24
# =========================================================
# URBANZATION
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 24
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'EIKWE'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V3-V4'} 1
# =========================================================
# DIET
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 24
# =========================================================
