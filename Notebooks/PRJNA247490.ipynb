# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA247490.csv")
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET", "CITYVILLAGE"] 
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    # if col=="COUNTRY":
    #     data.loc[pd.isna(data[col]), col] = "-"
        
    
    
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA247490.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA247490'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA247490'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {45.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'From an imbalance to a new imbalance: Italian-style gluten free_diet alters the salivary microbiota and metabolome of African celiac children'} 1
# =========================================================
# STUDY LINK
# -------------
# {26681599.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Amplicon'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Roche'} 1
# =========================================================
# COUNTRY
# -------------
# {nan} 1
# =========================================================
# DISEASE
# -------------
# {'Celiac disease'} 1
# =========================================================
# DOID
# -------------
# {10608.0} 1
# =========================================================
# STUDY DESIGN
# -------------
# {'Cohort study'} 1
# =========================================================
# BODY SITE
# -------------
# {'Oral'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-JUNIOR'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'Children aged in average 8 years old'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {521.0, 536.0, 540.0, 541.0, 542.0, 543.0, 547.0, 548.0, 549.0, 550.0, 551.0, 552.0, 553.0, 554.0, 555.0, 556.0, 557.0, 558.0, 559.0, 560.0, 561.0, 562.0, 566.0} 23
# =========================================================
# RUN ID
# -------------
# {'SRR1299251', 'SRR1299241', 'SRR1299225', 'SRR1299238', 'SRR1299228', 'SRR1299229', 'SRR1299240', 'SRR1299222', 'SRR1299224', 'SRR1299253', 'SRR1299249', 'SRR1299235', 'SRR1299243', 'SRR1299250', 'SRR1299252', 'SRR1299257', 'SRR1299262', 'SRR1299260', 'SRR1299255', 'SRR1299266', 'SRR1299263', 'SRR1299248', 'SRR1299239', 'SRR1299231', 'SRR1299230', 'SRR1299264', 'SRR1299223', 'SRR1299258', 'SRR1299256', 'SRR1299234', 'SRR1299246', 'SRR1299227', 'SRR1299226', 'SRR1299259', 'SRR1299236', 'SRR1299232', 'SRR1299261', 'SRR1299244', 'SRR1299247', 'SRR1299233', 'SRR1299242', 'SRR1299237', 'SRR1299245', 'SRR1299254', 'SRR1299265'} 45
# =========================================================
# Sample ID
# -------------
# {'SRS620568', 'SRS620545', 'SRS620535', 'SRS620540', 'SRS620544', 'SRS620550', 'SRS620572', 'SRS620549', 'SRS620537', 'SRS620567', 'SRS620536', 'SRS620577', 'SRS620576', 'SRS620564', 'SRS620546', 'SRS620539', 'SRS620551', 'SRS620542', 'SRS620566', 'SRS620541', 'SRS620554', 'SRS620573', 'SRS620534', 'SRS620561', 'SRS620563', 'SRS620569', 'SRS620571', 'SRS620570', 'SRS620574', 'SRS620557', 'SRS620578', 'SRS620552', 'SRS620538', 'SRS620560', 'SRS620555', 'SRS620562', 'SRS620558', 'SRS620565', 'SRS620543', 'SRS620548', 'SRS620575', 'SRS620556', 'SRS620547', 'SRS620553', 'SRS620559'} 45
# =========================================================
# Sample Name
# -------------
# {'7T0', '1T0', '32T60', '10T0', '30T60', '5T30', '6T60', '7T30', '11T30', '20T60', '2T60', '2T0', '13T30', '23T30', '9T30', '16T60', '1T30', '14T0', '28T60', '4T0', '21T30', '8T0', '11T0', '5T0', '14T60', '13T0', '17T30', '15T30', '25T30', '26T60', '27T30', '31T30', '18T60', '10T60', '9T0', '4T60', '19T30', '22T60', '12T60', '29T30', '3T0', '3T30', '8T60', '15T0', '24T60'} 45
# =========================================================
# COLLECTION DATE
# -------------
# {2013.0} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Single'} 1
# =========================================================
# LAT LON
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 45
# =========================================================
# SAMPLE TYPE
# -------------
# {'Saliva'} 1
# =========================================================
# ETHNICITY
# -------------
# {'Saharawi'} 1
# =========================================================
# ELO
# -------------
# {'Sahrawi'} 1
# =========================================================
# URBANZATION
# -------------
# {'Refugee camp'} 1
# =========================================================
# REGION
# -------------
# {'Western African Sahara'} 1
# =========================================================
# CITYVILLAGE
# -------------
# {nan} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V1-V3'} 1
# =========================================================
# DIET
# -------------
# {'Gluten free diet and African style dietary habits'} 1
# =========================================================
