# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA213674.csv")
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET", "CITYVILLAGE"] 
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA213674.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA213674'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA213674'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {66.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'High diversity of the saliva microbiome in Batwa Pygmies // Comparative analysis of the human saliva microbiome from different climate zones: Alaska, Germany and Africa'} 1
# =========================================================
# STUDY LINK
# -------------
# {'21858083 // 25515234'} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Amplicon'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Roche'} 1
# =========================================================
# COUNTRY
# -------------
# {'Democratic republic of the congo', 'Uganda', 'Sierra leone'} 3
# =========================================================
# DISEASE
# -------------
# {'Healthy'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 66
# =========================================================
# STUDY DESIGN
# -------------
# {'Cohort study'} 1
# =========================================================
# BODY SITE
# -------------
# {'Oral'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-FLX'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'Participants aged from 20 to 40 years old'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {256.0, 258.0, 259.0, 260.0, 261.0, 262.0, 263.0, 264.0, 266.0, 267.0, 207.0, 234.0, 237.0, 242.0, 243.0, 246.0, 247.0, 248.0, 249.0, 251.0, 252.0, 253.0, 254.0} 23
# =========================================================
# RUN ID
# -------------
# {'SRR945650', 'SRR945661', 'SRR945651', 'SRR945814', 'SRR945631', 'SRR945646', 'SRR945711', 'SRR945671', 'SRR945645', 'SRR945703', 'SRR945647', 'SRR945652', 'SRR945653', 'SRR945656', 'SRR945666', 'SRR945678', 'SRR945708', 'SRR945707', 'SRR945648', 'SRR945821', 'SRR945686', 'SRR945697', 'SRR945643', 'SRR945701', 'SRR945706', 'SRR945702', 'SRR945710', 'SRR945712', 'SRR945813', 'SRR945816', 'SRR945717', 'SRR945818', 'SRR945644', 'SRR945819', 'SRR945698', 'SRR945635', 'SRR945699', 'SRR945718', 'SRR945632', 'SRR945672', 'SRR945696', 'SRR945823', 'SRR945685', 'SRR945716', 'SRR945715', 'SRR945693', 'SRR945687', 'SRR945704', 'SRR945815', 'SRR945700', 'SRR945713', 'SRR945709', 'SRR945820', 'SRR945642', 'SRR945649', 'SRR945822', 'SRR945677', 'SRR945824', 'SRR945705', 'SRR945817', 'SRR945636', 'SRR945808', 'SRR945694', 'SRR945655', 'SRR945692', 'SRR945714'} 66
# =========================================================
# Sample ID
# -------------
# {'SRS465813', 'SRS465705', 'SRS465832', 'SRS465697', 'SRS465793', 'SRS465703', 'SRS465809', 'SRS465789', 'SRS465812', 'SRS465839', 'SRS465787', 'SRS465796', 'SRS465795', 'SRS465848', 'SRS465690', 'SRS465706', 'SRS465700', 'SRS465693', 'SRS465849', 'SRS465804', 'SRS465844', 'SRS465688', 'SRS465843', 'SRS465699', 'SRS465801', 'SRS465806', 'SRS465783', 'SRS465807', 'SRS465695', 'SRS465702', 'SRS465803', 'SRS465842', 'SRS465845', 'SRS465850', 'SRS465816', 'SRS465792', 'SRS465840', 'SRS465841', 'SRS465696', 'SRS465815', 'SRS465780', 'SRS465687', 'SRS465777', 'SRS465797', 'SRS465704', 'SRS465784', 'SRS465694', 'SRS465785', 'SRS465808', 'SRS465790', 'SRS465846', 'SRS465802', 'SRS465791', 'SRS465701', 'SRS465798', 'SRS465800', 'SRS465814', 'SRS465805', 'SRS465810', 'SRS465782', 'SRS465847', 'SRS465799', 'SRS465811', 'SRS465794', 'SRS465691', 'SRS465698'} 66
# =========================================================
# Sample Name
# -------------
# {'DRC37', 'BATWA_PYGMY65', 'SL17', 'DRC52', 'SL9', 'DRC60', 'BATWA_PYGMY51', 'BATWA_PYGMY49', 'BATWA_PYGMY20', 'BATWA_PYGMY60', 'DRC12', 'SL1', 'BATWA_PYGMY71', 'BATWA_PYGMY64', 'BATWA_PYGMY36', 'DRC69', 'SL2', 'BATWA_PYGMY19', 'SL25', 'DRC21', 'DRC45', 'BATWA_PYGMY66', 'SL57', 'SL89', 'BATWA_PYGMY56', 'BATWA_PYGMY47', 'DRC53', 'BATWA_PYGMY35', 'BATWA_PYGMY22', 'BATWA_PYGMY73', 'BATWA_PYGMY5', 'BATWA_PYGMY37', 'BATWA_PYGMY32', 'BATWA_PYGMY46', 'DRC76', 'BATWA_PYGMY72', 'BATWA_PYGMY7', 'SL65', 'DRC61', 'DRC68', 'BATWA_PYGMY55', 'DRC92', 'SL49', 'SL81', 'BATWA_PYGMY26', 'DRC84', 'DRC44', 'BATWA_PYGMY61', 'BATWA_PYGMY67', 'BATWA_PYGMY23', 'BATWA_PYGMY70', 'BATWA_PYGMY11', 'BATWA_PYGMY45', 'BATWA_PYGMY58', 'DRC36', 'SL33', 'BATWA_PYGMY83', 'BATWA_PYGMY54', 'BATWA_PYGMY53', 'BATWA_PYGMY1', 'BATWA_PYGMY27', 'SL73', 'BATWA_PYGMY52', 'BATWA_PYGMY24', 'SL41', 'BATWA_PYGMY63'} 66
# =========================================================
# COLLECTION DATE
# -------------
# {'4/25/2008', '10/21/2008'} 2
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Single'} 1
# =========================================================
# LAT LON
# -------------
# {'8.482050, -13.213670', '-4.441931, 15.266293', '0.347596, 32.582520*'} 3
# =========================================================
# SAMPLE TYPE
# -------------
# {'Saliva'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan, 'Batwa'} 2
# =========================================================
# ELO
# -------------
# {nan, 'Twa'} 2
# =========================================================
# URBANZATION
# -------------
# {'Rural', 'Urban'} 2
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'Freetown', 'Mpungo // Mukongoro // Kitariro // Nyakatare // Bikuto commuinities of buhoma', 'Kinshasa'} 3
# =========================================================
# TARGET AMPLICON
# -------------
# {'V1-V2'} 1
# =========================================================
# DIET
# -------------
# {'Farmer lifestyle', 'Hunter gatherers diet'} 2
# =========================================================
