# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/mgp16608.csv")
data.loc[data["PLATFORM"]=='454 GS-FLXTitanium', "PLATFORM"] = '454 GS-FLX TITANIUM'
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET","CITYVILLAGE"]
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values
# set(data["PLATFORM"])
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

data["AVERAGE SPOTLENGTH"] = 0 # Unknown/missing value 
data.to_csv("../Corrected/mgp16608.csv")
# Out:
# REPOSITORY ID
# -------------
# {'MGP16608'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'MGP16608'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {57.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'Gut microbiome of coexisting Baaka Pygmies and Bantu reflects gradients of traditional subsistence patterns'} 1
# =========================================================
# STUDY LINK
# -------------
# {26923597.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Amplicon'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Roche'} 1
# =========================================================
# COUNTRY
# -------------
# {'Central African republic'} 1
# =========================================================
# DISEASE
# -------------
# {'Healthy'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 57
# =========================================================
# STUDY DESIGN
# -------------
# {'Cohort study'} 1
# =========================================================
# BODY SITE
# -------------
# {'Gut'} 1
# =========================================================
# PLATFORM
# -------------
# {'454 GS-FLX TITANIUM'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {nan} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 57
# =========================================================
# RUN ID
# -------------
# {'MGM4682498.3', 'MGM4682481.3', 'MGM4682477.3', 'MGM4682510.3', 'MGM4682493.3', 'MGM4682507.3', 'MGM4682473.3', 'MGM4682517.3', 'MGM4682495.3', 'MGM4682491.3', 'MGM4682505.3', 'MGM4682483.3', 'MGM4682479.3', 'MGM4682468.3', 'MGM4682469.3', 'MGM4682474.3', 'MGM4682488.3', 'MGM4682475.3', 'MGM4682492.3', 'MGM4682512.3', 'MGM4682497.3', 'MGM4682464.3', 'MGM4682519.3', 'MGM4682486.3', 'MGM4682490.3', 'MGM4682502.3', 'MGM4682503.3', 'MGM4682496.3', 'MGM4682494.3', 'MGM4682509.3', 'MGM4682484.3', 'MGM4682501.3', 'MGM4682500.3', 'MGM4682480.3', 'MGM4682476.3', 'MGM4682478.3', 'MGM4682471.3', 'MGM4682472.3', 'MGM4682467.3', 'MGM4682499.3', 'MGM4682516.3', 'MGM4682506.3', 'MGM4682466.3', 'MGM4682482.3', 'MGM4682470.3', 'MGM4682513.3', 'MGM4682518.3', 'MGM4682487.3', 'MGM4682520.3', 'MGM4682465.3', 'MGM4682514.3', 'MGM4682504.3', 'MGM4682511.3', 'MGM4682485.3', 'MGM4682515.3', 'MGM4682489.3', 'MGM4682508.3'} 57
# =========================================================
# Sample ID
# -------------
# {'INNQEGM02.HU_502', 'HCZRAFT02.HU_104', 'INNQEGM02.HU_522', 'INNQEGM02.HU_524', 'HCZRAFT02.HU_122', 'HCZRAFT02.HU_105', 'INNQEGM02.HU_501', 'HCZRAFT02.HU_115', 'HCZRAFT02.HU_102', 'HCZRAFT02.HU_112', 'HCZRAFT02.HU_119', 'HCZRAFT02.HU_114', 'HCZRAFT02.HU_99', 'INNQEGM02.HU_504', 'INNQEGM02.HU_523', 'INNQEGM02.HU_528', 'HCZRAFT02.HU_118', 'INNQEGM02.HU_525', 'INNQEGM02.HU_526', 'HCZRAFT02.HU_108', 'INNQEGM02.HU_518', 'HCZRAFT02.HU_110', 'INNQEGM02.HU_538', 'INNQEGM02.HU_532', 'INNQEGM02.HU_505', 'HCZRAFT02.HU_124', 'INNQEGM02.HU_539', 'INNQEGM02.HU_540', 'HCZRAFT02.HU_101', 'HCZRAFT02.HU_103', 'HCZRAFT02.HU_109', 'INNQEGM02.HU_508', 'HCZRAFT02.HU_107', 'INNQEGM02.HU_500', 'INNQEGM02.HU_507', 'HCZRAFT02.HU_121', 'HCZRAFT02.HU_100', 'HCZRAFT02.HU_106', 'HCZRAFT02.HU_120', 'HCZRAFT02.HU_113', 'HCZRAFT02.HU_123', 'INNQEGM02.HU_506', 'INNQEGM02.HU_536', 'HCZRAFT02.HU_116', 'INNQEGM02.HU_517', 'HCZRAFT02.HU_111', 'INNQEGM02.HU_531', 'INNQEGM02.HU_527', 'INNQEGM02.HU_529', 'HCZRAFT02.HU_117', 'INNQEGM02.HU_535', 'INNQEGM02.HU_503', 'INNQEGM02.HU_521', 'INNQEGM02.HU_537', 'INNQEGM02.HU_533', 'INNQEGM02.HU_530', 'INNQEGM02.HU_534'} 57
# =========================================================
# Sample Name
# -------------
# {'MGS437957', 'MGS437942', 'MGS437945', 'MGS438068', 'MGS438011', 'MGS438071', 'MGS437975', 'MGS438032', 'MGS437984', 'MGS438026', 'MGS437969', 'MGS438014', 'MGS438050', 'MGS437924', 'MGS438062', 'MGS438065', 'MGS437936', 'MGS437996', 'MGS437954', 'MGS438008', 'MGS438077', 'MGS437927', 'MGS437921', 'MGS438080', 'MGS437963', 'MGS437915', 'MGS438017', 'MGS437981', 'MGS437930', 'MGS437978', 'MGS437987', 'MGS438041', 'MGS437966', 'MGS437972', 'MGS438059', 'MGS438053', 'MGS437960', 'MGS438005', 'MGS438020', 'MGS437939', 'MGS437948', 'MGS438044', 'MGS438074', 'MGS438035', 'MGS437993', 'MGS437951', 'MGS438002', 'MGS438023', 'MGS438047', 'MGS438056', 'MGS437999', 'MGS437990', 'MGS438038', 'MGS437918', 'MGS438029', 'MGS437933', 'MGS437912'} 57
# =========================================================
# COLLECTION DATE
# -------------
# {'06/15/2010'} 1
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Paired'} 1
# =========================================================
# LAT LON
# -------------
# {'4.394673, 18.558189*'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'Stool'} 1
# =========================================================
# ETHNICITY
# -------------
# {'Baaka // Bantu'} 1
# =========================================================
# ELO
# -------------
# {'Aka // Bantu central'} 1
# =========================================================
# URBANZATION
# -------------
# {'Rural'} 1
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'Dzanga sangha'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V1-V3'} 1
# =========================================================
# DIET
# -------------
# {'Traditional diet'} 1
# =========================================================
