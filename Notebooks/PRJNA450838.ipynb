# =========================================================
# Sample Name
# -------------
# {'CHILDSTOOLCOMP2_V4', 'CHILDSTOOL11_V4', 'CHILDSTOOL11_V3V4', 'ADULTSTOOL3_V3V4', 'CGHANDS4_V3V4', 'CHILDSTOOL3_V4', 'CHILDSTOOL6_V3V4', 'CHILDSTOOL12_V4', 'CGHANDS13_V3V4', 'CHILDHANDS3_V3V4', 'CHILDSTOOL17_V3V4', 'CHILDSTOOL5_V3V4', 'CHILDSTOOL9_V4', 'CHILDSTOOL6_V4', 'CHILDSTOOL2_V3V4', 'CHILDSTOOL13_V3V4', 'CGHANDS16_V3V4', 'CGHANDS14_V3V4', 'CHILDSTOOL15_V4', 'CHILDSTOOL7_V3V4', 'CHILDSTOOL13_V4', 'CHILDHANDS5_V3V4', 'CHILDHANDS2_V3V4', 'CHILDSTOOL10_V4', 'CHILDSTOOL18_V3V4', 'CHILDSTOOL12_V3V4', 'ADULTSTOOL4_V3V4', 'CHILDSTOOLCOMP1_V3V4', 'CGHANDS3_V3V4', 'CGHANDS5_V3V4', 'ADULTSTOOL2_V4', 'CHILDSTOOL2_V4', 'ADULTSTOOL5_V4', 'CGHANDS1_V3V4', 'CHILDSTOOLCOMP2_V3V4', 'CGHANDS17_V3V4', 'CGHANDS15_V3V4', 'CHILDSTOOL16_V4', 'CHILDSTOOL9_V3V4', 'CHILDHANDS1_V3V4', 'ADULTSTOOLCOMP2_V4', 'ADULTSTOOL6_V3V4', 'CHILDSTOOL16_V3V4', 'CHILDSTOOL14_V4', 'ADULTSTOOLCOMP2_V3V4', 'CGHANDS12_V3V4', 'CHILDSTOOL7_V4', 'CHILDSTOOL1_V3V4', 'ADULTSTOOL6_V4', 'CHILDSTOOL14_V3V4', 'CHILDSTOOL15_V3V4', 'CHILDSTOOL5_V4', 'ADULTSTOOL5_V3V4', 'ADULTSTOOL2_V3V4', 'ADULTSTOOL4_V4', 'ADULTSTOOL1_V4', 'CHILDSTOOL18_V4', 'CHILDHANDS4_V3V4', 'ADULTSTOOLCOMP1_V4', 'CGHANDS10_V3V4', 'CHILDHANDS10_V3V4', 'CHILDSTOOL4_V4', 'CHILDSTOOL10_V3V4', 'CGHANDS2_V3V4', 'CHILDSTOOL17_V4', 'CGHANDS9_V3V4', 'CHILDHANDS6_V3V4', 'CHILDSTOOL1_V4', 'CGHANDS11_V3V4', 'CGHANDS8_V3V4', 'CHILDSTOOL3_V3V4', 'CHILDHANDS11_V3V4', 'ADULTSTOOL1_V3V4', 'CHILDSTOOL4_V3V4', 'CHILDHANDS8_V3V4', 'CHILDSTOOL8_V4', 'CHILDHANDS9_V3V4', 'CGHANDS6_V3V4', 'CGHANDS7_V3V4', 'ADULTSTOOL3_V4', 'CHILDHANDS7_V3V4', 'ADULTSTOOLCOMP1_V3V4', 'CHILDSTOOL8_V3V4', 'CHILDSTOOLCOMP1_V4'} 84
# =========================================================
# COLLECTION DATE
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 84
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Paired'} 1
# =========================================================
# LAT LON
# -------------
# {'-1.292066, 36.821945'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'Stool'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan} 1
# =========================================================
# ELO
# -------------
# {nan} 1
# =========================================================
# URBANZATION
# -------------
# {'Urban'} 1
# =========================================================
# REGION
# -------------
# {'Kibera'} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'Nairobi'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V4', 'V3-V4'} 2
# =========================================================
# DIET
# -------------
# {nan} 1
# =========================================================
