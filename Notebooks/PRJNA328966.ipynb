# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA328966.csv")
from replacements import replacement_func
cols = ["STUDY TITLE","ASSAY TYPE","TECHNOLOGY","COUNTRY","DISEASE","STUDY DESIGN","BODY SITE","PARTICIPANT FEATURES","ETHNICITY","ELO", "LIBRARY LAYOUT","BODY SITE", "URBANZATION", "SAMPLE TYPE","REGION","DIET", "CITYVILLAGE"] 
data[cols] = data[cols].applymap(lambda x: replacement_func(x) if type(x)==str else x).values
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        if col not in cols:
            data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA328966.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA328966'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA328966'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {28.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'Gut microbiome alterations in patients with stage 4 Hepatitis C'} 1
# =========================================================
# STUDY LINK
# -------------
# {27625705.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'Amplicon'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'Illumina'} 1
# =========================================================
# COUNTRY
# -------------
# {'Egypt'} 1
# =========================================================
# DISEASE
# -------------
# {'Hcv', 'Healthy'} 2
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 1883.0} 17
# =========================================================
# STUDY DESIGN
# -------------
# {'Case-control'} 1
# =========================================================
# BODY SITE
# -------------
# {'Gut'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA MISEQ'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'Adult males  aging between 21 and 65'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {251.0} 1
# =========================================================
# RUN ID
# -------------
# {'SRR3889532', 'SRR3889527', 'SRR3889548', 'SRR3889538', 'SRR3889531', 'SRR3889546', 'SRR3889539', 'SRR3889530', 'SRR3889547', 'SRR3889550', 'SRR3889525', 'SRR3889540', 'SRR3889549', 'SRR3889545', 'SRR3889541', 'SRR3889523', 'SRR3889535', 'SRR3889542', 'SRR3889524', 'SRR3889534', 'SRR3889537', 'SRR3889543', 'SRR3889533', 'SRR3889526', 'SRR3889529', 'SRR3889536', 'SRR3889544', 'SRR3889528'} 28
# =========================================================
# Sample ID
# -------------
# {'SRS1560517', 'SRS1560519', 'SRS1560531', 'SRS1560524', 'SRS1560522', 'SRS1560540', 'SRS1560532', 'SRS1560528', 'SRS1560525', 'SRS1560527', 'SRS1560539', 'SRS1560541', 'SRS1560536', 'SRS1560535', 'SRS1560529', 'SRS1560515', 'SRS1560521', 'SRS1560537', 'SRS1560520', 'SRS1560530', 'SRS1560533', 'SRS1560518', 'SRS1560538', 'SRS1560526', 'SRS1560523', 'SRS1560534', 'SRS1560514', 'SRS1560516'} 28
# =========================================================
# Sample Name
# -------------
# {'HCV_GM__AMA_P3_R1', 'HEALTHY_GM_AMA_H7_R1', 'HEALTHY_GM_AMA_H1_R2', 'HEALTHY_GM_AMA_H4_R1', 'HEALTHY_GM_AMA_H8_R1', 'HCV_GM__AMA_P1_R1', 'HEALTHY_GM_AMA_H8_R2', 'HEALTHY_GM_AMA_H5_R1', 'HCV_GM__AMA_P2_R1', 'HEALTHY_GM_AMA_H3_R1', 'HCV_GM__AMA_P6_R2', 'HEALTHY_GM_AMA_H4_R2', 'HEALTHY_GM_AMA_H7_R2', 'HEALTHY_GM_AMA_H1_R1', 'HEALTHY_GM_AMA_H3_R2', 'HCV_GM__AMA_P4_R1', 'HCV_GM__AMA_P6_R1', 'HEALTHY_GM_AMA_H2_R1', 'HCV_GM__AMA_P3_R2', 'HEALTHY_GM_AMA_H6_R1', 'HEALTHY_GM_AMA_H2_R2', 'HEALTHY_GM_AMA_H6_R2', 'HCV_GM__AMA_P4_R2', 'HCV_GM__AMA_P5_R1', 'HCV_GM__AMA_P5_R2', 'HEALTHY_GM_AMA_H5_R2', 'HCV_GM__AMA_P2_R2', 'HCV_GM__AMA_P1_R2'} 28
# =========================================================
# COLLECTION DATE
# -------------
# {'05/05/2015', '02/22/2015'} 2
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'Paired'} 1
# =========================================================
# LAT LON
# -------------
# {'29.076360, 31.097000'} 1
# =========================================================
# SAMPLE TYPE
# -------------
# {'Stool'} 1
# =========================================================
# ETHNICITY
# -------------
# {nan} 1
# =========================================================
# ELO
# -------------
# {nan} 1
# =========================================================
# URBANZATION
# -------------
# {'Camp'} 1
# =========================================================
# REGION
# -------------
# {nan} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'Beni-suef'} 1
# =========================================================
# TARGET AMPLICON
# -------------
# {'V4'} 1
# =========================================================
# DIET
# -------------
# {nan} 1
# =========================================================
