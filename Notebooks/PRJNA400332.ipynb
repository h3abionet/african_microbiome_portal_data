# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../Originals/Fragmented/PRJNA400332.csv")
for col in data.columns:
    data.loc[pd.isna(data[col]), col] = np.nan
    data.loc[data[col]=="-", col] = np.nan
    try:
        data[col] = data[col].apply(lambda x: x.upper().strip())
        data.loc[data[col]=="", col] = np.nan
    except:
        pass
    
    print(col)
    print("-------------")
    print(set(data[col]), len(set(data[col])))
    
    print("=========================================================")

    
data.to_csv("../Corrected/PRJNA400332.csv")
# Out:
# REPOSITORY ID
# -------------
# {'PRJNA400332'} 1
# =========================================================
# REPOSITORY LINK
# -------------
# {'PRJNA400332'} 1
# =========================================================
# SAMPLE NUMBER
# -------------
# {50.0} 1
# =========================================================
# STUDY TITLE
# -------------
# {'IMPACT OF A NOMADIC PASTORAL LIFESTYLE ON THE GUT MICROBIOME IN THE FULANI LIVING IN NIGERIA'} 1
# =========================================================
# STUDY LINK
# -------------
# {31572342.0} 1
# =========================================================
# ASSAY TYPE
# -------------
# {'AMPLICON'} 1
# =========================================================
# TECHNOLOGY
# -------------
# {'ILLUMINA'} 1
# =========================================================
# COUNTRY
# -------------
# {'NIGERIA'} 1
# =========================================================
# DISEASE
# -------------
# {'HEALTHY'} 1
# =========================================================
# DOID
# -------------
# {nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan} 50
# =========================================================
# STUDY DESIGN
# -------------
# {'COHORT STUDY'} 1
# =========================================================
# BODY SITE
# -------------
# {'GUT'} 1
# =========================================================
# PLATFORM
# -------------
# {'ILLUMINA MISEQ'} 1
# =========================================================
# PARTICIPANT FEATURES
# -------------
# {'PARTICIPANTS AGED BETWEEN 2 AND 70  YEARS OLD'} 1
# =========================================================
# AVERAGE SPOTLENGTH
# -------------
# {590.0, 591.0} 2
# =========================================================
# RUN ID
# -------------
# {'SRR5983203', 'SRR5983198', 'SRR5983228', 'SRR5983233', 'SRR5983207', 'SRR5983193', 'SRR5983239', 'SRR5983238', 'SRR5983211', 'SRR5983197', 'SRR5983201', 'SRR5983227', 'SRR5983210', 'SRR5983217', 'SRR5983213', 'SRR5983206', 'SRR5983196', 'SRR5983226', 'SRR5983215', 'SRR5983216', 'SRR5983219', 'SRR5983204', 'SRR5983208', 'SRR5983222', 'SRR5983232', 'SRR5983194', 'SRR5983192', 'SRR5983237', 'SRR5983229', 'SRR5983200', 'SRR5983220', 'SRR5983231', 'SRR5983190', 'SRR5983202', 'SRR5983209', 'SRR5983223', 'SRR5983205', 'SRR5983224', 'SRR5983235', 'SRR5983221', 'SRR5983212', 'SRR5983225', 'SRR5983199', 'SRR5983191', 'SRR5983214', 'SRR5983195', 'SRR5983234', 'SRR5983230', 'SRR5983236', 'SRR5983218'} 50
# =========================================================
# Sample ID
# -------------
# {'SRS2472120', 'SRS2472082', 'SRS2472105', 'SRS2472073', 'SRS2472091', 'SRS2472088', 'SRS2472094', 'SRS2472112', 'SRS2472100', 'SRS2472076', 'SRS2472109', 'SRS2472119', 'SRS2472113', 'SRS2472102', 'SRS2472090', 'SRS2472101', 'SRS2472096', 'SRS2472104', 'SRS2472095', 'SRS2472111', 'SRS2472083', 'SRS2472099', 'SRS2472078', 'SRS2472114', 'SRS2472085', 'SRS2472084', 'SRS2472092', 'SRS2472121', 'SRS2472077', 'SRS2472103', 'SRS2472098', 'SRS2472081', 'SRS2472097', 'SRS2472106', 'SRS2472074', 'SRS2472086', 'SRS2472079', 'SRS2472110', 'SRS2472116', 'SRS2472108', 'SRS2472089', 'SRS2472115', 'SRS2472122', 'SRS2472107', 'SRS2472080', 'SRS2472087', 'SRS2472117', 'SRS2472075', 'SRS2472093', 'SRS2472118'} 50
# =========================================================
# Sample Name
# -------------
# {'A07', 'A25', 'A33', 'A20', 'A31', 'A41', 'A26', 'A11', 'A06', 'A22', 'A24', 'A35', 'A09', 'A08', 'A39', 'A50', 'A10', 'A27', 'A29', 'A15', 'A42', 'A16', 'A04', 'A28', 'A46', 'A49', 'A19', 'A38', 'A12', 'A48', 'A02', 'A43', 'A21', 'A37', 'A17', 'A30', 'A44', 'A14', 'A45', 'A34', 'A51', 'A01', 'A03', 'A36', 'A47', 'A40', 'A23', 'A13', 'A32', 'A18'} 50
# =========================================================
# COLLECTION DATE
# -------------
# {'09/19/2016', '09/30/2016', '10/10/2016', '10/21/2016', '11/18/2016', '11/20/2016', '11/22/2016', '10/05/2016', '10/17/2016', '11/21/2016', '11/19/2016', '09/26/2016', '10/13/2016', '09/18/2016', '10/09/2016', '09/16/2016', '11/17/2016', '09/24/2016', '10/01/2016', '09/28/2016', '09/13/2016', '10/14/2016', '10/15/2016', '11/13/2016', '11/16/2016', '11/14/2016', '09/29/2016', '09/11/2016', '09/27/2016', '09/10/2016', '09/20/2016', '10/06/2016', '10/18/2016', '10/11/2016', '09/25/2016', '10/07/2016', '10/08/2016', '10/19/2016', '09/21/2016', '10/12/2016', '09/22/2016', '11/15/2016', '09/15/2016', '09/12/2016', '09/14/2016', '09/17/2016', '10/20/2016', '11/12/2016', '10/16/2016', '09/23/2016'} 50
# =========================================================
# LIBRARY LAYOUT
# -------------
# {'PAIRED'} 1
# =========================================================
# LAT LON
# -------------
# {'10.242000, 8.767770', '9.896527, 8.858331'} 2
# =========================================================
# SAMPLE TYPE
# -------------
# {'STOOL'} 1
# =========================================================
# ETHNICITY
# -------------
# {'FULANI', 'JARAWA'} 2
# =========================================================
# ELO
# -------------
# {'FULANI', 'JARAWA'} 2
# =========================================================
# URBANZATION
# -------------
# {'RURAL'} 1
# =========================================================
# REGION
# -------------
# {'PLATEAU STATE'} 1
# =========================================================
# CITYVILLAGE
# -------------
# {'JENGRE', 'JOS'} 2
# =========================================================
# TARGET AMPLICON
# -------------
# {'V4'} 1
# =========================================================
# DIET
# -------------
# {'DIETARY HABITS AVAILABLE'} 1
# =========================================================
